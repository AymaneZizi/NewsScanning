# %%
import json
from watson_developer_cloud import NaturalLanguageUnderstandingV1
from watson_developer_cloud.natural_language_understanding_v1 \
  import Features, EmotionOptions,  CategoriesOptions, ConceptsOptions, EntitiesOptions, KeywordsOptions, MetadataOptions

natural_language_understanding = NaturalLanguageUnderstandingV1(
  username='50b362f6-6ef7-4bd6-8696-5981245ffe24',
  password='VS4M0eK3MWh5',
  version='2018-03-16')

test_url = 'http://calgaryherald.com/news/politics/braid-last-ditch-pipeline-talks-bring-threat-of-quick-oil-squeeze'
#test_url = 'https://www.ledroit.com/actualites/ottawa/14-millions--de-plus-a-oc-transpo-473c4469be246adf3a523d67b4a67232'

#6 features
response = natural_language_understanding.analyze(
  url=test_url,
  features=Features(
      emotion=EmotionOptions(),
      categories=CategoriesOptions(),
      concepts=ConceptsOptions(limit=3),
      entities=EntitiesOptions(
          emotion=True,
          sentiment=True,
          limit=2),
      keywords=KeywordsOptions(
          emotion=True,
          sentiment=True,
          limit=2),
      metadata=MetadataOptions()
      ))

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 3515,
#     "features": 6
#   },
#   "retrieved_url": "http://calgaryherald.com/news/politics/braid-last-ditch-pipeline-talks-bring-threat-of-quick-oil-squeeze",
#   "language": "en",
#   "emotion": {
#     "document": {
#       "emotion": {
#         "sadness": 0.516196,
#         "disgust": 0.158425,
#         "fear": 0.159607,
#         "anger": 0.505643,
#         "joy": 0.176153
#       }
#     }
#   },
#   "keywords": [
#     {
#       "text": "Premier Rachel Notley",
#       "relevance": 0.901645,
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       }
#     },
#     {
#       "text": "Kinder Morgan",
#       "relevance": 0.863784,
#       "emotion": {
#         "sadness": 0.204937,
#         "disgust": 0.106363,
#         "fear": 0.082057,
#         "anger": 0.121032,
#         "joy": 0.133915
#       },
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       }
#     }
#   ],
#   "metadata": {
#     "image": "https://postmediacalgaryherald2.files.wordpress.com/2018/05/notley-horgan-1.png",
#     "publication_date": "2018-05-22T00:00:00",
#     "title": "Braid: Last-ditch pipeline talks bring threat of quick oil squeeze",
#     "feeds": [
#       {
#         "link": "http://calgaryherald.com/feed/"
#       }
#     ],
#     "authors": [
#       {
#         "name": "Calgary Herald"
#       }
#     ]
#   },
#   "concepts": [
#     {
#       "text": "Federal government of the United States",
#       "relevance": 0.928023,
#       "dbpedia_resource": "http://dbpedia.org/resource/Federal_government_of_the_United_States"
#     },
#     {
#       "text": "Alberta New Democratic Party",
#       "relevance": 0.702098,
#       "dbpedia_resource": "http://dbpedia.org/resource/Alberta_New_Democratic_Party"
#     },
#     {
#       "text": "Alberta",
#       "relevance": 0.700633,
#       "dbpedia_resource": "http://dbpedia.org/resource/Alberta"
#     }
#   ],
#   "categories": [
#     {
#       "score": 0.602853,
#       "label": "/business and industrial/energy/oil"
#     },
#     {
#       "score": 0.481377,
#       "label": "/law, govt and politics/government"
#     },
#     {
#       "score": 0.351798,
#       "label": "/travel/tourist destinations/canada"
#     }
#   ],
#   "entities": [
#     {
#       "text": "Rachel Notley",
#       "type": "Person",
#       "emotion": {
#         "sadness": 0.498425,
#         "disgust": 0.105774,
#         "fear": 0.155679,
#         "anger": 0.506599,
#         "joy": 0.508879
#       },
#       "sentiment": {
#         "score": -0.288429,
#         "label": "negative"
#       },
#       "relevance": 0.805188,
#       "count": 10,
#       "disambiguation": {
#         "dbpedia_resource": "http://dbpedia.org/resource/Rachel_Notley",
#         "name": "Rachel Notley",
#         "subtype": []
#       }
#     },
#     {
#       "text": "Cheryl Oates",
#       "type": "Person",
#       "emotion": {
#         "sadness": 0.62266,
#         "disgust": 0.143131,
#         "fear": 0.111178,
#         "anger": 0.1516,
#         "joy": 0.097628
#       },
#       "sentiment": {
#         "score": -0.340911,
#         "label": "negative"
#       },
#       "relevance": 0.539204,
#       "count": 6
#     }
#   ]
# }
